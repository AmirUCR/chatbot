# %%
# %run nltk_chat.ipynb
import time

pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today?",]
    ],
     [
        r"what('s)? (is)? your name",
        ["My name is Jeeves", "I'm Jeeves", "I'm Jeeves. What's yours?"]
    ],
    [
        r"i'm (good|well|ok)",
        ["Good to hear that :)",]
    ],
    [
        r"i('m)? (tired|sad|bored)",
        ["I'm sorry to hear that :(",]
    ],
    [
        r"sorry (.*)",
        ["It's alright", "It's OK, never mind",]
    ],
    [
        r"i'm doing (well|ok)",
        ["Nice to hear that", "Alright :)",]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there",]
    ],
    [
        r"how old (.*)",
        ["I am currently about three weeks old :D",]
        
    ],
    [
        r"what (.*) want",
        ["Make me an offer I can't refuse",]
        
    ],
    [
        r"(where|what) (.*) (live|location|city)",
        ['California',]
    ],
    [
        r"how('s)? (is)?.*the weather in (.*)",
        ["Weather in %3 is sunny like always", "it's too hot here in %3"]
    ],
    [
        r"(.*)raining in (.*)",
        ["No rain since last week here in %2","Damn its raining too much here in %2"]
    ],
    [
        r"how are you",
        ["I'm kinda buggy. Amir is working to fix me.", "I'm doing good. How about You?"]
    ],
    [
        r"(.*) (sports|game)",
        ["I'm a very big fan of video games",]
    ],
    [
        r"(.*) (joke)",
        ["What did the man say to his dead robot? Rust in peace."]
    ],
    [
        r"quit",
        ["Ba bye!", "Bye! Take care. See you soon :)", "It was nice talking to you. See you soon :)", "Ciao!"]
    ],
    [
        r"(ok|okay)",
        [" "]
    ],
    [
        r"who('s)? (is)? (.*)",
        ["I'm not sure. Let me look that up for you."]
    ]
]

def spell_check(sentence):
    return

def chatty():
    greetings = "Hey there. I'm a chatbot.\nI guess I'm here to talk to you. Say \"quit\" to leave."
    print(greetings)
    text_to_speech(greetings)
    time.sleep(5)
    
    chat = Chat(pairs, reflections)
    chat.converse()

# %%
chatty()
